# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
data = pd.read_csv('Diabetes Prediction.csv')

# %%
X = data.iloc[:, 0:8].values
y = data.iloc[:, 8].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units = 6, activation = 'relu'))

# %%
ann.add(tf.keras.layers.Dense(units = 6, activation = 'relu'))

# %%
ann.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size = 8, epochs = 30)
# Out:
# Epoch 1/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6729 - accuracy: 0.6685
# Epoch 2/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6046 - accuracy: 0.6946
# Epoch 3/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5672 - accuracy: 0.7188
# Epoch 4/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5445 - accuracy: 0.7393
# Epoch 5/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.7542
# Epoch 6/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5143 - accuracy: 0.7579
# Epoch 7/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7598
# Epoch 8/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.7598
# Epoch 9/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.7561
# Epoch 10/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.7542
# Epoch 11/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4775 - accuracy: 0.7598
# Epoch 12/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.7616
# Epoch 13/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.7691
# Epoch 14/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4683 - accuracy: 0.7691
# Epoch 15/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7709
# Epoch 16/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.7691
# Epoch 17/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.7728
# Epoch 18/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4616 - accuracy: 0.7672
# Epoch 19/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.7765
# Epoch 20/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7728
# Epoch 21/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4580 - accuracy: 0.7728
# Epoch 22/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7728
# Epoch 23/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.7728
# Epoch 24/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.7747
# Epoch 25/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7747
# Epoch 26/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7728
# Epoch 27/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.7709
# Epoch 28/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4523 - accuracy: 0.7784
# Epoch 29/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.7747
# Epoch 30/30
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.7765

# %%
y_predict = ann.predict(X_test)
y_predict = (y_predict > 0.5)
y_predict
# Out:
# array([[ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_predict)
print(cm)
accuracy_score(y_test, y_predict)
# Out:
# [[133  24]
#  [ 29  45]]
# 0.7705627705627706
